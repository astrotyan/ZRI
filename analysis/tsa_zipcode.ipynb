# %% [markdown]
# # Libraries and Settings

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm

# %% [markdown]
# # Import Data

# %%
raw = pd.read_csv('../data/zri/Zip_Zri_AllHomesPlusMultifamily.csv')
raw.columns = raw.columns.str.replace('RegionName', 'zip')

# %%
region = raw.iloc[:,:7].set_index('zip')

# %%
region
# Out:
#        RegionID       City State                             Metro  \
# zip
# 10025     61639   New York    NY       New York-Newark-Jersey City
# 60657     84654    Chicago    IL          Chicago-Naperville-Elgin
# 10023     61637   New York    NY       New York-Newark-Jersey City
# 77494     91982       Katy    TX  Houston-The Woodlands-Sugar Land
# 60614     84616    Chicago    IL          Chicago-Naperville-Elgin
# ...         ...        ...   ...                               ...
# 26291     68966   Snowshoe    WV                               NaN
# 12720     62697     Bethel    NY                               NaN
# 26209     68924   Snowshoe    WV                               NaN
# 41101     75924    Ashland    KY                Huntington-Ashland
# 89155     95851  Las Vegas    NV      Las Vegas-Henderson-Paradise
#
#               CountyName  SizeRank
# zip
# 10025    New York County         1
# 60657        Cook County         2
# 10023    New York County         3
# 77494      Harris County         4
# 60614        Cook County         5
# ...                  ...       ...
# 26291  Pocahontas County     13177
# 12720    Sullivan County     13178
# 26209  Pocahontas County     13179
# 41101        Boyd County     13180
# 89155       Clark County     13181
#
# [13181 rows x 6 columns]

# %%
data = pd.concat([raw['zip'],raw.iloc[:,11:-1]],axis=1).set_index('zip')

# %% [markdown]
# # Data Cleaning

# %%
sns.heatmap(data.isnull(), cbar=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ModuleNotFoundError: No module named 'numpy.core._multiarray_umath'

# %%
missingness = [np.mean(data.isna().sum(axis=1) < i) for i in range(12*9+1)]
plt.scatter(range(12*9+1),missingness)

# %%
data = data[data.isna().sum(axis=1) < 20]

# %%
data.shape
# Out:
# (13181, 108)

# %% [markdown]
# # Time Series Analysis for a Single Zip Code

# %% [markdown]
# ## ZRI vs Time

# %%
zip_number = 10025
zipcode = data.loc[data.index==zip_number,:].T
zipcode.index = pd.to_datetime(zipcode.index)
zipcode.columns = ['zri']
zipcode.plot()
plt.xlabel('Year')
plt.ylabel('Zillow Rent Index')
plt.title('New York, 10006')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-ec549f8255a9> in <module>
#       2 zipcode = data.loc[data.index==zip_number,:].T
#       3 zipcode.index = pd.to_datetime(zipcode.index)
# ----> 4 zipcode.columns = ['zri']
#       5 zipcode.plot()
#       6 plt.xlabel('Year')
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5190         try:
#    5191             object.__getattribute__(self, name)
# -> 5192             return object.__setattr__(self, name, value)
#    5193         except AttributeError:
#    5194             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     688
#     689     def _set_axis(self, axis, labels):
# --> 690         self._data.set_axis(axis, labels)
#     691         self._clear_item_cache()
#     692
#
# /usr/local/lib/python3.7/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     181             raise ValueError(
#     182                 "Length mismatch: Expected axis has {old} elements, new "
# --> 183                 "values have {new} elements".format(old=old_len, new=new_len)
#     184             )
#     185
#
# ValueError: Length mismatch: Expected axis has 0 elements, new values have 1 elements

# %% [markdown]
# ## Monthly Trend

# %%
zipcode['year'] = zipcode.index.year
zipcode['month'] = zipcode.index.month
for y in range(2011,2020):
    plt.plot('month','zri',data = zipcode.loc[zipcode['year'] == y,:])
    plt.text(zipcode.loc[zipcode.year==y, :].shape[0]+1, zipcode.loc[zipcode.year==y, 'zri'][-1:].values[0], y)
plt.xlabel('Month')
plt.ylabel('Zillow Rent Index')
plt.title('New York, 10006')
# Out:
# Text(0.5, 1.0, 'New York, 10006')

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomp = seasonal_decompose(zipcode['zri'], model='multiplicative', extrapolate_trend='freq')
plt.plot(decomp.trend*decomp.seasonal,color='r',label='Trend*Seasonal')
plt.plot(zipcode['zri'],color='b',label='Observed')
plt.xlabel('Year')
plt.ylabel('Zillow Rent Index')
plt.title('New York, 10006')
plt.legend()

# %%
plt.scatter(decomp.resid.index,decomp.resid);

# %%
decomp.plot();

# %% [markdown]
# ## Order of Differencing

# %%
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plt.rcParams.update({'figure.figsize':(8,6), 'figure.dpi':120})

# Original Series
fig, axes = plt.subplots(3, 2,sharex='col')
axes[0, 0].plot(zipcode['zri']); axes[0, 0].set_title('Original Series')
plot_acf(zipcode['zri'], ax=axes[0, 1])

# 1st Differencing
axes[1, 0].plot(zipcode['zri'].diff().dropna()); axes[1, 0].set_title('1st Order Differencing')
plot_acf(zipcode['zri'].diff().dropna(), ax=axes[1, 1])

# 2nd Differencing
axes[2, 0].plot(zipcode['zri'].diff().diff().dropna()); axes[2, 0].set_title('2nd Order Differencing')
plot_acf(zipcode['zri'].diff().diff().dropna(), ax=axes[2, 1]);

# %% [markdown]
# ##  Order of the AR Term

# %%
plt.rcParams.update({'figure.figsize':(9,3), 'figure.dpi':120})

fig, axes = plt.subplots(1, 2)
axes[0].plot(zipcode['zri'].diff()); axes[0].set_title('1st Differencing')
plot_pacf(zipcode['zri'].diff().dropna(), ax=axes[1]);

# %% [markdown]
# ## Seasonal Autoregression Model

# %%
train_zip = zipcode['2011':'2018']
test_zip = zipcode['2019']

# %%
mod = sm.tsa.statespace.SARIMAX(train_zip['zri'], order=(1,1,0), seasonal_order=(1,1,0,12),freq='MS')
# %time fitted = mod.fit(disp=False)
# print(res.summary())
print(res.arparams[0])
print(res.seasonalarparams[0])
print(res.pvalues[:2])
# Out:
# CPU times: user 239 ms, sys: 24.9 ms, total: 264 ms
# Wall time: 165 ms
# 0.696552377491518
# -0.529192314129369
# ar.L1       4.462620e-14
# ar.S.L12    1.107229e-09
# dtype: float64

# %%
conf
# Out:
#               lower zri    upper zri
# 2019-01-01  3668.482028  3737.793974
# 2019-02-01  3648.530517  3785.029128
# 2019-03-01  3635.559944  3839.274214
# 2019-04-01  3615.376930  3883.705750
# 2019-05-01  3597.773005  3927.115637
# 2019-06-01  3586.471795  3972.998088
# 2019-07-01  3572.716827  4012.722134
# 2019-08-01  3558.510800  4048.567760
# 2019-09-01  3553.665141  4090.674597
# 2019-10-01  3536.490636  4117.683100
# 2019-11-01  3509.428198  4132.342415
# 2019-12-01  3480.077820  4142.530190

# %%
# Forecast
fc = fitted.forecast(test_zip['zri'].shape[0])
pred = fitted.get_prediction(start='2019-01',end='2019-12')
conf = pred.conf_int()# 95% conf

lower_series = conf.iloc[:, 0]
upper_series = conf.iloc[:, 1]
plt.figure(figsize=(6,4), dpi=100)
plt.plot(train_zip['zri'], label='training')
plt.plot(test_zip['zri'], label='actual')
plt.plot(fc, label='forecast')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.15)
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %%
tss = np.sum((test_zip['zri']-test_zip['zri'].mean())**2)
rss = np.sum((test_zip['zri']-fc)**2)
1-rss/tss # R^2
# Out:
# 0.5498463893502874

# %%
(tss/test_zip['zri'].shape[0])**0.5 # RMSE
# Out:
# 52.06859791552763

# %% [markdown]
# # Select Zip Codes by Alex's List

# %%
with open('alex_zip_codes.txt','r') as f:
    alex_zip = f.readlines()

# %%
alex_zip = alex_zip[0][1:-1].split(', ')

# %%
alex_zip = list(map(lambda x: int(x[1:-1]),alex_zip))

# %% [markdown]
# # Train/Test Split

# %%
train = data.iloc[data.index.isin(alex_zip),:-12]
test = data.iloc[data.index.isin(alex_zip),-12:]

# %% [markdown]
# # Impute

# %%
train = train.interpolate(method='linear',limit_direction='both', axis=1)
test = test.interpolate(method='linear',limit_direction='both', axis=1)

# %% [markdown]
# # Build a Time Series Model for Each Zip Code

# %%
# one = train.iloc[0,:]
# mod = sm.tsa.statespace.SARIMAX(one, order=(1,1,0), seasonal_order=(1,1,0,12),freq='MS')
# %time res = mod.fit(disp=False)
# # print(res.summary())
# print(res.arparams[0])
# print(res.seasonalarparams[0])
# print(res.pvalues[:2])

# %%
stat = pd.DataFrame(np.zeros(shape=(train.shape[0],4)),index=train.index,columns=['ar','p(ar)','s','p(s)'])
predict = pd.DataFrame(np.zeros(shape=(train.shape[0],12)),index=train.index,columns=[str(i) for i in range(1,13)])

# %%
# About 40 minutes
import warnings
warnings.filterwarnings('ignore')
nzip = train.shape[0]
for i in range(nzip):
    one = train.iloc[i,:]
    mod = sm.tsa.statespace.SARIMAX(one, order=(1,1,0), seasonal_order=(1,1,0,12),freq='MS')
    res = mod.fit(disp=False)
    stat.iloc[i,:] = [res.arparams[0],res.pvalues[0],res.seasonalarparams[0],res.pvalues[1]]
    predict.iloc[i,:] = res.predict('2019-01','2019-12').to_list()
#     print(i,' out of ', nzip)
#     print(stat.iloc[i,:])
#     print(predict.iloc[i,:])

# %% [markdown]
# ## Percentage Errors

# %%
pe = pd.DataFrame(np.zeros(shape=(train.shape[0],1)),index=train.index,columns=['Percentage Error'])
for i in range(nzip):
    testone = test.iloc[i,:].to_numpy()
    predictone = predict.iloc[i,:].to_numpy()
    pe.iloc[i,:] = np.sum(abs(predictone-testone)/testone)/12.

# %%
pe.hist(bins=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x13457dc10>]],
#       dtype=object)

# %%
np.mean(pe)
# Out:
# Percentage Error    0.028326
# dtype: float64

# %% [markdown]
# ## Distribution of Coefficients

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,3), dpi=100)
stat['ar'].hist(bins=100,ax=axes[0])
stat['s'].hist(bins=100,ax=axes[1])

# %% [markdown]
# ## Residuals

# %%
plt.figure(figsize=(8,4))
plt.scatter(test.mean(axis=1),predict.mean(axis=1)-test.mean(axis=1))
plt.xlabel('Zillow Rent Index in 2019')
plt.ylabel('Residual')
plt.title('Forcast - Actual')
# Out:
# Text(0.5, 1.0, 'Forcast - Actual')

# %%
plt.figure(figsize=(8,4))
plt.scatter(test.mean(axis=1),(predict.mean(axis=1)-test.mean(axis=1))/test.mean(axis=1))
plt.xlabel('Zillow Rent Index in 2019')
plt.ylabel('Percentage Error')
plt.title('(Forcast - Actual) / Actual')
# Out:
# Text(0.5, 1.0, '(Forcast - Actual) / Actual')

# %%
import math
tss = np.sum((test.mean(axis=1)-test.mean(axis=1).mean())**2)
rss = np.sum((test.mean(axis=1)-predict.mean(axis=1))**2)
1-rss/tss
# Out:
# 0.9931933517746357

# %%
(rss/test.shape[0])**0.5
# Out:
# 49.56690021272748

# %%
predict.columns = test.columns

rmse_bm = (np.sum((predict - test)**2)/test.shape[0]).map(math.sqrt)
rmse_bm.plot(c='r',label = 'Time Series')

toy_model = pd.concat([train.iloc[:,-1]]*12,axis=1)
toy_model.columns = test.columns

rmse_toy = (np.sum((toy_model - test)**2)/test.shape[0]).map(math.sqrt)
rmse_toy.plot(c='b',label = '2018-12')

plt.xlabel('Month')
plt.ylabel('RMSE')
plt.legend()

# %%
R2_bm = 1-np.sum((test-predict)**2)/np.sum((test-test.mean())**2)
R2_bm.plot(c='r',label = 'Time Series')

R2_toy = 1-np.sum((test-toy_model)**2)/np.sum((test-test.mean())**2)
R2_toy.plot(c='b',label = '2018-12')

plt.xlabel('Month')
plt.ylabel('R^2')
plt.legend()

# %% [markdown]
# ## Outliers

# %%
res = pd.concat([test.mean(axis=1),predict.mean(axis=1),pe],axis=1)
res.columns = ['ZRI','Predict','Percentage Error']

# %%
outlier = pe['Percentage Error'] > 0.2

# %%
region.merge(res[outlier],on='zip').sort_values('Percentage Error')
# Out:
#        RegionID                 City State                        Metro  \
# zip
# 7738      60784  Middletown Township    NJ  New York-Newark-Jersey City
# 66064     87076           Osawatomie    KS                  Kansas City
# 27557     69410            Middlesex    NC                  Rocky Mount
# 49097     79583            Vicksburg    MI            Kalamazoo-Portage
# 46952     78364               Marion    IN                       Marion
# 12828     62775  Town of Fort Edward    NY                  Glens Falls
# 85365     94941                 Yuma    AZ                         Yuma
# 36323     73832                 Elba    AL                   Enterprise
# 80238     93314               Denver    CO       Denver-Aurora-Lakewood
# 85364     94940                 Yuma    AZ                         Yuma
# 16242     64513    Mahoning Township    PA                   Pittsburgh
# 85350     94926             Somerton    AZ                         Yuma
# 46989     78389               Upland    IN                       Marion
# 35674     73576            Tuscumbia    AL       Florence-Muscle Shoals
# 12809     62760       Town of Argyle    NY                  Glens Falls
# 11934     62285      Center Moriches    NY  New York-Newark-Jersey City
#
#               CountyName  SizeRank          ZRI      Predict  Percentage Error
# zip
# 7738     Monmouth County     10634  2639.750000  2094.778005          0.206001
# 66064       Miami County     10786   819.833333   991.145812          0.209110
# 27557        Nash County      9502   906.083333  1098.555957          0.212178
# 49097   Kalamazoo County      8277   924.000000  1117.588140          0.212179
# 46952       Grant County      5036   725.541667   894.347661          0.239449
# 12828  Washington County      8689  1283.416667  1606.695055          0.252379
# 85365        Yuma County      1051   976.666667   708.606252          0.274175
# 36323      Coffee County      9633   947.458333  1217.674966          0.286714
# 80238      Denver County      4711  2109.833333  1479.624076          0.298668
# 85364        Yuma County       159   909.666667   637.511203          0.299017
# 16242   Armstrong County     11350   782.916667  1017.017442          0.302980
# 85350        Yuma County      7394   874.416667   608.747466          0.303598
# 46989       Grant County     12424   739.750000   960.909257          0.304885
# 35674     Colbert County      5238   832.750000   554.570025          0.334040
# 12809  Washington County     12285  1320.958333  1789.115861          0.357015
# 11934     Suffolk County      9829  2457.000000  3410.495187          0.388073

# %%
# train[outlier].T.plot(figsize=(12,12))

# %%
outlier.index
# Out:
# Int64Index([60657, 77494, 60614, 77449, 77084, 79936, 60640, 11226, 10467,
#             78660,
#             ...
#             96148, 97149, 95497, 84762, 95335, 92341, 26291, 12720, 41101,
#             89155],
#            dtype='int64', name='zip', length=11048)

# %%
raw.loc[raw.index.isin(pe[outlier].index),:]
# Out:
#        RegionID    zip                City State  \
# 7738      89449  72212         Little Rock    AR
# 11934     65277  17960  West Penn Township    PA
# 12809     94230  83622          Idaho City    ID
# 12828     80645  51239                Hull    IA
#
#                                       Metro         CountyName  SizeRank  \
# 7738   Little Rock-North Little Rock-Conway     Pulaski County      7739
# 11934                            Pottsville  Schuylkill County     11935
# 12809                            Boise City       Boise County     12810
# 12828                                   NaN       Sioux County     12829
#
#        2010-09  2010-10  2010-11  ...  2019-04  2019-05  2019-06  2019-07  \
# 7738     867.0      NaN    961.0  ...   1235.0   1241.0   1242.0   1232.0
# 11934      NaN      NaN      NaN  ...      NaN    869.0    860.0    847.0
# 12809      NaN      NaN      NaN  ...   1183.0   1187.0   1198.0   1220.0
# 12828      NaN      NaN      NaN  ...    978.0    967.0    961.0    951.0
#
#        2019-08  2019-09  2019-10  2019-11  2019-12  2020-01
# 7738    1227.0   1224.0   1216.0   1193.0   1201.0   1198.0
# 11934    843.0    854.0    879.0    871.0    867.0    864.0
# 12809   1239.0   1253.0      NaN   1295.0   1298.0   1293.0
# 12828    943.0    940.0    957.0    952.0    955.0    965.0
#
# [4 rows x 120 columns]

# %%
pe[outlier].index
# Out:
# Int64Index([85364, 85365, 80238, 46952, 35674, 85350, 49097, 12828, 27557,
#             36323, 11934,  7738, 66064, 16242, 12809, 46989],
#            dtype='int64', name='zip')
